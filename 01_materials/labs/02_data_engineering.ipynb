 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2025-09-26 16:25:47,114, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2025-09-26 16:25:47,120, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2025-09-26 16:25:47,129, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2025-09-26 16:25:47,141, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2025-09-26 16:25:47,147, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-09-26 16:25:48,552, 473192941.py, 5, INFO, Writing data ((239659, 9)) to csv took 1.271763563156128 seconds.
# 2025-09-26 16:25:48,552, 473192941.py, 6, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2025-09-26 16:25:49,898, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 0.7280383110046387 seconds.
# 2025-09-26 16:25:49,900, 817812245.py, 8, INFO, Parquet file size 9.713265 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\jjsos\AppData\Local\Temp\ipykernel_26572\102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32     float64  float64
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(4d34027), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000016F3CADD700>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# ticker
# ACN    2018-01-02  153.500000  154.100006  152.779999  153.839996  148.655960
# ACN    2018-01-03  152.990005  154.990005  152.990005  154.550003  149.342056
# ACN    2018-01-04  155.000000  156.860001  154.770004  156.380005  151.110382
# ACN    2018-01-05  156.610001  157.720001  156.130005  157.669998  152.356918
# ACN    2018-01-08  157.369995  159.009995  156.839996  158.929993  153.574463
# ...           ...         ...         ...         ...         ...         ...
# ZIXI   2003-06-26    4.040000    4.190000    3.860000    4.000000    4.000000
# ZIXI   2003-06-27    4.000000    4.050000    3.790000    3.850000    3.850000
# ZIXI   2003-06-30    3.840000    4.000000    3.720000    3.770000    3.770000
# ZIXI   2003-07-01    3.720000    3.850000    3.650000    3.780000    3.780000
# ZIXI   2003-07-02    3.810000    3.990000    3.730000    3.730000    3.730000
#
#            Volume    source  Year  Close_lag_1   Returns
# ticker
# ACN     3061900.0   ACN.csv  2018          NaN       NaN
# ACN     2064200.0   ACN.csv  2018   153.839996  0.004615
# ACN     1777000.0   ACN.csv  2018   154.550003  0.011841
# ACN     1597600.0   ACN.csv  2018   156.380005  0.008249
# ACN     2616900.0   ACN.csv  2018   157.669998  0.007991
# ...           ...       ...   ...          ...       ...
# ZIXI     515300.0  ZIXI.csv  2003     4.040000 -0.009901
# ZIXI     162400.0  ZIXI.csv  2003     4.000000 -0.037500
# ZIXI     119900.0  ZIXI.csv  2003     3.850000 -0.020779
# ZIXI     202100.0  ZIXI.csv  2003     3.770000  0.002653
# ZIXI      81100.0  ZIXI.csv  2003     3.780000 -0.013228
#
# [239659 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-09-26 16:26:33,605, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-09-26 16:26:33,606, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-09-26 16:26:33,637, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2025-09-26 16:26:33,637, data_manager.py, 74, INFO, Selecting sample of files
# 2025-09-26 16:26:33,641, data_manager.py, 80, INFO, Selected 30 files
# 2025-09-26 16:26:33,641, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\GIL.csv
# 2025-09-26 16:26:33,641, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\GIL.csv
# 2025-09-26 16:26:33,648, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:34,130, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\CEMB.csv
# 2025-09-26 16:26:34,132, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\CEMB.csv
# 2025-09-26 16:26:34,139, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:34,319, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CXDC.csv
# 2025-09-26 16:26:34,321, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CXDC.csv
# 2025-09-26 16:26:34,327, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:34,619, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CAPL.csv
# 2025-09-26 16:26:34,619, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CAPL.csv
# 2025-09-26 16:26:34,626, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:34,812, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\MMX.csv
# 2025-09-26 16:26:34,813, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MMX.csv
# 2025-09-26 16:26:34,818, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:34,924, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BDCS.csv
# 2025-09-26 16:26:34,926, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BDCS.csv
# 2025-09-26 16:26:34,934, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:35,166, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\UMPQ.csv
# 2025-09-26 16:26:35,169, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\UMPQ.csv
# 2025-09-26 16:26:35,185, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:35,674, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\TTEK.csv
# 2025-09-26 16:26:35,675, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TTEK.csv
# 2025-09-26 16:26:35,688, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:36,285, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\PTH.csv
# 2025-09-26 16:26:36,285, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\PTH.csv
# 2025-09-26 16:26:36,299, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:36,607, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\IMRA.csv
# 2025-09-26 16:26:36,607, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\IMRA.csv
# 2025-09-26 16:26:36,614, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:36,637, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\SPMD.csv
# 2025-09-26 16:26:36,638, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\SPMD.csv
# 2025-09-26 16:26:36,646, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:36,873, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\SKYW.csv
# 2025-09-26 16:26:36,873, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SKYW.csv
# 2025-09-26 16:26:36,890, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:37,585, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\FUSB.csv
# 2025-09-26 16:26:37,585, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\FUSB.csv
# 2025-09-26 16:26:37,595, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,034, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ACA.csv
# 2025-09-26 16:26:38,034, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ACA.csv
# 2025-09-26 16:26:38,038, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,098, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\ULST.csv
# 2025-09-26 16:26:38,098, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\ULST.csv
# 2025-09-26 16:26:38,106, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,272, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\PST.csv
# 2025-09-26 16:26:38,272, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\PST.csv
# 2025-09-26 16:26:38,280, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,545, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\JHMF.csv
# 2025-09-26 16:26:38,545, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\JHMF.csv
# 2025-09-26 16:26:38,552, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,672, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\BUYN.csv
# 2025-09-26 16:26:38,672, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\BUYN.csv
# 2025-09-26 16:26:38,675, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:38,760, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\NYMX.csv
# 2025-09-26 16:26:38,760, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\NYMX.csv
# 2025-09-26 16:26:38,771, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:39,300, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\CCZ.csv
# 2025-09-26 16:26:39,300, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CCZ.csv
# 2025-09-26 16:26:39,314, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:39,752, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\XLRE.csv
# 2025-09-26 16:26:39,752, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\XLRE.csv
# 2025-09-26 16:26:39,757, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:39,884, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BLBD.csv
# 2025-09-26 16:26:39,884, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BLBD.csv
# 2025-09-26 16:26:39,895, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,271, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\GNW.csv
# 2025-09-26 16:26:40,271, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\GNW.csv
# 2025-09-26 16:26:40,284, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,619, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ACST.csv
# 2025-09-26 16:26:40,619, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ACST.csv
# 2025-09-26 16:26:40,627, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,805, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\OPTN.csv
# 2025-09-26 16:26:40,805, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\OPTN.csv
# 2025-09-26 16:26:40,811, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,894, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\FLCB.csv
# 2025-09-26 16:26:40,894, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\FLCB.csv
# 2025-09-26 16:26:40,901, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,944, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\MREO.csv
# 2025-09-26 16:26:40,945, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MREO.csv
# 2025-09-26 16:26:40,945, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:40,986, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\ENIA.csv
# 2025-09-26 16:26:40,986, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ENIA.csv
# 2025-09-26 16:26:41,000, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:41,561, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\etfs\FALN.csv
# 2025-09-26 16:26:41,561, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\etfs\FALN.csv
# 2025-09-26 16:26:41,567, data_manager.py, 101, INFO, Saving data by year
# 2025-09-26 16:26:41,671, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv\stocks\BIOC.csv
# 2025-09-26 16:26:41,671, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BIOC.csv
# 2025-09-26 16:26:41,671, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-09-26 16:26:41,836, data_manager.py, 131, INFO, Creating features data.
# 2025-09-26 16:26:41,840, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-09-26 16:26:42,226, data_manager.py, 150, INFO, Creating features
# c:\Users\jjsos\Documents\DSI_7\Production\01_materials\labs\../../05_src\stock_prices\data_manager.py:153: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('ticker', group_keys=False)
# 2025-09-26 16:26:42,236, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
